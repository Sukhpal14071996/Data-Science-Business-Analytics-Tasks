# %% [markdown]
# # Sukhpal

# %% [markdown]
# ## DATA SCIENCE AND BUSINESS ANALYTICS INTERN @ THE SPARKS FOUNDATION

# %% [markdown]
# ## TASK 3: EXPLORATORY DATA ANALYSIS - RETAIL

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset = pd.read_csv("SampleSuperstore.csv")
dataset.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
print("Total Observations: ", dataset.shape[0],
      "\nTotal Parameters: ",dataset.shape[1])
# Out:
# Total Observations:  9994
# Total Parameters:  13

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
dataset.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# There is not any null value in the dataset.

# %%
dataset.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# The column Country has only one unique value i.e. United States and it will not be useful for the particular dataset. So, I am dropimg it.

# %%
dataset.drop(columns = 'Country')
dataset.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
dataset.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Sales vs Profit

# %%
plt.scatter(x = dataset['Sales'], y = dataset['Profit'], color = 'red')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.title('Sales vs Profit')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(dataset['Sales'],color='red',label='Sales',shade=True)
sns.kdeplot(dataset['Profit'],color='Blue',label='Profit',shade=True)
plt.xlim([-100,1000])
plt.legend()
plt.show()

# %% [markdown]
# Profit is more than that of sale but there are some areas where profit could be increased.

# %% [markdown]
# ## [1] Based on the category

# %%
sns.pairplot(dataset,hue='Category')
plt.show()

# %% [markdown]
# ## [2] Based on Region

# %%
sns.pairplot(dataset,hue='Region')
plt.show()

# %% [markdown]
# ## [3] based on the Segment

# %%
sns.pairplot(dataset,hue='Segment')
plt.show()

# %%
dataset.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# ## Heatmap for Correlation

# %%
plt.figure(dpi = 150)
sns.heatmap(dataset.corr(), cmap = 'rocket_r', annot = True)
plt.show()

# %% [markdown]
# From above Heatmap:
#
# <p>Sales and Profit are Moderately Correlated.
# <p>Discount and Profit are Negatively Correlated.
# <p>Quantity and Profit are less Moderately Correlated.

# %% [markdown]
# ## Count plot of each column

# %%
fig,axs=plt.subplots(nrows=2,ncols=2,figsize=(20,10))
sns.countplot(x=dataset['Category'],ax=axs[0][0])
sns.countplot(x=dataset['Segment'],ax=axs[0][1])
sns.countplot(x=dataset['Ship Mode'],ax=axs[1][0])
sns.countplot(x=dataset['Region'],ax=axs[1][1])
axs[0][0].set_title('Category',fontsize=20)
axs[0][1].set_title('Segment',fontsize=20)
axs[1][0].set_title('Ship Mode',fontsize=20)
axs[1][1].set_title('Region',fontsize=20)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.countplot(x=dataset['Sub-Category'])
plt.title('Sub-Category',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.countplot(x = dataset['State'])
plt.xticks(rotation=90)
plt.title('State',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.countplot(x = dataset['Quantity'])
plt.title('Quantity',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.countplot(x = dataset['Discount'])
plt.xticks(rotation=90)
plt.title('Discount',fontsize=20)
plt.show()

# %% [markdown]
# ## Distribution of the data using the plot

# %%
fig, axs = plt.subplots(ncols=2, nrows = 2, figsize = (10,10))
sns.histplot(x=dataset['Sales'], color = 'red',  ax = axs[0][0])
sns.histplot(x=dataset['Profit'], color = 'green',  ax = axs[0][1])
sns.histplot(x=dataset['Quantity'], color = 'orange',  ax = axs[1][0])
sns.histplot(x=dataset['Discount'], color = 'blue',  ax = axs[1][1])
axs[0][0].set_title('Sales Distribution', fontsize = 20)
axs[0][1].set_title('Profit Distribution', fontsize = 20)
axs[1][0].set_title('Quantity distribution', fontsize = 20)
axs[1][1].set_title('Discount Distribution', fontsize = 20)
plt.show()

# %% [markdown]
# ## Statewise Deal Analysis

# %%
dataset['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
data = dataset['State'].value_counts()
data.head(10)
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
data.plot(kind='bar',figsize=(20,5), color = 'magenta')
plt.ylabel('Frequency / Number of deals')
plt.xlabel('States')

plt.title('State Wise Dealings', fontsize = 20)
plt.show()

# %% [markdown]
# <b>Here is top 3 state where deals are Highest.</b>
# <p>1. Califonia
# <p>2. New York
# <p>3. Texas

# %%
print("Average number of deal per state: ", dataset['State'].value_counts().mean())
# Out:
# Average number of deal per state:  203.9591836734694

# %% [markdown]
# ## City Wise analysis of the dealing

# %%
data1 = dataset['City'].value_counts()
data1 = data1.head(50)
data1
# Out:
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
# Houston          377
# Chicago          314
# Columbus         222
# San Diego        170
# Springfield      163
# Dallas           157
# Jacksonville     125
# Detroit          115
# Newark            95
# Richmond          90
# Jackson           82
# Columbia          81
# Aurora            68
# Phoenix           63
# Long Beach        61
# Arlington         60
# San Antonio       59
# Louisville        57
# Miami             57
# Rochester         53
# Charlotte         52
# Henderson         51
# Lakewood          49
# Lancaster         46
# Milwaukee         45
# Fairfield         45
# Denver            44
# Lawrence          44
# Baltimore         43
# Pasadena          42
# Cleveland         42
# San Jose          42
# Fayetteville      41
# Salem             40
# Atlanta           39
# Austin            39
# Franklin          37
# Huntsville        36
# ...

# %%
data1.plot(kind='bar',figsize=(20,5), color = 'orange')
plt.ylabel('Frequency / Number of deals')
plt.xlabel('City')

plt.title('City Wise Dealings', fontsize = 20)
plt.show()

# %% [markdown]
# <b>Here is top 3 city where deals are Highest.</b>
#
# <p>1. New York City
# <p>2. Los Angeles
# <p>3. Philadelphia

# %%
print("Average number of deal per city: ",dataset['City'].value_counts().mean())
# Out:
# Average number of deal per city:  18.821092278719398

# %% [markdown]
# ## Segment wise analysis of Profit, Discount and Sales

# %%
dataset['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
data2= dataset.groupby(['Segment'])[['Sales', 'Discount', 'Profit']].mean()
data2
# Out:
#                   Sales  Discount     Profit
# Segment
# Consumer     223.733644  0.158141  25.836873
# Corporate    233.823300  0.158228  30.456667
# Home Office  240.972041  0.147128  33.818664

# %% [markdown]
# ### Sales, Profit and Discount

# %%
data2.plot.pie(normalize=True,
               subplots=True, 
                    autopct='%1.1f%%',
                    figsize=(20, 20),
                    startangle=90,     # start angle 90° (Africa)
                    shadow=True,
                    labels = data2.index)
plt.title('Segment wise analysis of Sale, Discount, profit')
plt.show()

# %% [markdown]
# <b>Sales:</b>
#
# <ul><li>Consumer : 32%</li>
# <li>Corporate - 33.5%</li>
# <li>Home Office : 34.5%</li></ul>
#
# <b>Discount :</b>
#
# <ul><li>Consumer : 15.8%</li>
# <li>Corporate : 15.8%</li>
# <li>Home Office : 14.7%</li></ul>
#
# <b>Profit :</b>
#
# <ul><li>Consumer : 28.7%</li>
# <li>Corporate : 33.8%</li>
# <li>Home Office : 37.5%</li></ul>

# %% [markdown]
# ## Statewise analysis of Profit Discount and Sales

# %%
dataset['State'].value_counts().head()
# Out:
# California      2001
# New York        1128
# Texas            985
# Pennsylvania     587
# Washington       506
# Name: State, dtype: int64

# %%
data_state = dataset.groupby(['State'])[['Sales', 'Discount', 'Profit']].mean()
data_state.head()
# Out:
#                  Sales  Discount     Profit
# State
# Alabama     319.846557  0.000000  94.865989
# Arizona     157.508933  0.303571 -15.303235
# Arkansas    194.635500  0.000000  66.811452
# California  228.729451  0.072764  38.171608
# Colorado    176.418231  0.316484 -35.867351

# %% [markdown]
# ### [1] Stepwise Profit Analysis

# %%
data_state1=data_state.sort_values('Profit')

data_state1[['Profit']].plot(kind = 'bar', figsize = (20,5), color = 'green')
plt.title('State wise Profit Analysis', fontsize = 20)
plt.ylabel('Profit per Sate')
plt.xlabel('States')
plt.show()

# %% [markdown]
# <b>RESULT</b>
#
# <ul><b><li>Vermont:</b> Highest Profit</li>
#
# <b><li>Ohio:</b> Lowest Profit</li></ul>

# %% [markdown]
# ### [2] Statewise Sale Analysis

# %%
data_state['Sales'].plot(kind='pie',
                        figsize = (20,20),
                        autopct='%1.1f%%',
                        startangle=90,     # start angle 90° (Africa)
                        shadow=True)
plt.title('State wise analysis of Sale',fontsize=20)
plt.show()

# %% [markdown]
# <ul><li>Highest amount of sales = <b>Wyoming(11.8%)</b>
# <li>Lowest amount of sales = <b>South Dakota(0.8%)</b>

# %% [markdown]
# ### [3] Statewise Discount Analysis

# %%
data_state1['Discount'].sort_values(ascending = False).head(20).plot(kind='bar',figsize=(20,5), color = 'purple')
plt.title('State wise analysis of Discount', fontsize=20)
plt.show()

# %% [markdown]
# #### Illinois is at the top

# %% [markdown]
# ## Citywise Analysis of the Profit

# %%
data_city= dataset.groupby(['City'])[['Sales', 'Discount', 'Profit']].mean()
data_city = data_city.sort_values('Profit')
data_city.head()
# Out:
#                  Sales  Discount      Profit
# City
# Bethlehem   337.926800  0.380000 -200.619160
# Champaign   151.960000  0.600000 -182.352000
# Oswego      107.326000  0.600000 -178.709200
# Round Rock  693.436114  0.274286 -169.061614
# Lancaster   215.031826  0.315217 -157.371052

# %% [markdown]
# ### [1] Low Profit

# %%
data_city['Profit'].sort_values(ascending = True).head(20).plot(kind='bar',figsize=(20,5),color = 'Red')
plt.title('City wise analysis of Sale, Discount, profit')
plt.show()

# %% [markdown]
# <b>Bethlehem</b> has the lowest profit and in negative so, it has highest loss

# %% [markdown]
# ### [2] High Profit

# %%
data_city['Profit'].sort_values(ascending = False).head(20).plot(kind='bar',figsize=(20,5),color = 'Red')
plt.title('City wise analysis of Sale, Discount, profit')
plt.show()

# %% [markdown]
# <b>Jamestown</b> has the highest profit.

# %% [markdown]
# ## Quantity wise Sales, Profit and Discount Analysis

# %%
data_quantity = dataset.groupby(['Quantity'])[['Sales', 'Discount', 'Profit']].mean()
data_quantity.head()
# Out:
#                Sales  Discount     Profit
# Quantity
# 1          59.234632  0.152959   8.276396
# 2         120.354488  0.154858  16.006831
# 3         175.201578  0.153329  23.667715
# 4         271.764059  0.157708  37.131310
# 5         337.936339  0.157146  40.257394

# %% [markdown]
# ### Sales, Discount and Profit

# %%
data_quantity.plot.pie(subplots=True, 
                    autopct='%1.1f%%',
                    figsize=(20, 20),
                     pctdistance=0.69,
                    startangle=90,     # start angle 90° (Africa)
                    shadow=True,
                    labels = data_quantity.index)
plt.title('Quantity wise analysis of Sale, Discount, profit')
plt.show()

# %% [markdown]
# ## Category wise Sales, Discount and Profit

# %%
data_category = dataset.groupby(['Category'])[['Sales', 'Discount', 'Profit']].mean()
data_category
# Out:
#                       Sales  Discount     Profit
# Category
# Furniture        349.834887  0.173923   8.699327
# Office Supplies  119.324101  0.157285  20.327050
# Technology       452.709276  0.132323  78.752002

# %%
data_category.plot.pie(normalize=True,
                       subplots=True, 
                     figsize=(20, 20), 
                     autopct='%1.1f%%', 
                     labels = data_category.index)
plt.show()

# %% [markdown]
# <ul><li>Maximun sales and Profit obtain in <b>Technology</b>.</li>
# <li>Minimun profit obtain in <b>Furniture</b>.</li></ul>

# %% [markdown]
# ## Sub-Category wise Sales, Profit and Discount

# %%
data_sub_category = dataset.groupby(['Sub-Category'])[['Sales', 'Discount', 'Profit']].mean()
data_sub_category.head()
# Out:
#                    Sales  Discount     Profit
# Sub-Category
# Accessories   215.974604  0.078452  54.111788
# Appliances    230.755710  0.166524  38.922758
# Art            34.068834  0.074874   8.200737
# Binders       133.560560  0.372292  19.843574
# Bookcases     503.859633  0.211140 -15.230509

# %% [markdown]
# ### [1] Based on the Sales

# %%
plt.figure(figsize = (20,20))
plt.pie(data_sub_category['Sales'], labels = data_sub_category.index, autopct = '%1.1f%%')
plt.title('Sub-Category Wise Sales Analysis', fontsize = 20)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### Copier then Machine have High sales.

# %% [markdown]
# ### [2] Based on the Discount

# %%
plt.figure(figsize = (20,20))
plt.pie(data_sub_category['Discount'], labels = data_sub_category.index, autopct = '%1.1f%%')
plt.title('Sub-Category Wise Discount Analysis', fontsize = 20)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### Binders , Machines and then tables have high Discount.

# %% [markdown]
# ### [3] Based on the Profit

# %%
data_sub_category[['Sales','Profit']].sort_values('Profit', ascending = False).plot(kind='bar',
                                                              figsize= (20,5),
                                                              label=['Avg Sales Price($)','Profit($)'])
plt.show()

# %% [markdown]
# #### Copiers has highest Profit and Sales

# %% [markdown]
# ## Region wise Analysis

# %%
data_region = dataset.groupby(['Region'])[['Sales', 'Discount', 'Profit']].mean()
data_region
# Out:
#               Sales  Discount     Profit
# Region
# Central  215.772661  0.240353  17.092709
# East     238.336110  0.145365  32.135808
# South    241.803645  0.147253  28.857673
# West     226.493233  0.109335  33.849032

# %%
data_region.plot.pie(normalize=True,
                     subplots=True, 
                   figsize=(20, 20), 
                   autopct='%1.1f%%',
                   labels = data_region.index)
plt.show()

# %% [markdown]
# #### West has highest Profit

# %% [markdown]
# ## Ship Mode wise analysis

# %%
dataset['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
data_shipmode = dataset.groupby(['Ship Mode'])[['Sales', 'Discount', 'Profit']].mean()

# %%
data_shipmode.plot.pie(normalize=True,
                       subplots=True,
                     figsize=(20, 20), 
                     autopct='%1.1f%%', 
                     labels = data_shipmode.index)
plt.show()

# %% [markdown]
# <ul><li>Profit and Discount is high in First Class
# <li>Sales is high for Same day ship

# %% [markdown]
# ## Result and Conclusion

# %% [markdown]
# <ul>
# <li>Profit is more than that of sale but there are some areas where profit could be increased.
# <li>Profit and Discount is high in First Class
# <li>Sales is high for Same day ship
# <li>Sub-category: Copier: High Profit & sales
# <li>Sub-category: Binders , Machines and then tables have high Discount.
# <li>Category: Maximun sales and Profit obtain in Technology.
# <li>Category: Minimun profit obtain in Furniture
# <li>State: Vermont: Highest Profit
# <li>State: Ohio: Lowest Profit
# <li>Segment: Home-office: High Profit & sales
# <li>Here is top 3 city where deals are Highest.
# <ol><li>New York City
# <li>Los Angeles
# <li>Philadelphia<ol></ul>
# <ul><li>Sales and Profit are Moderately Correlated.
# <li>Quantity and Profit are less Moderately Correlated.
# <li>Discount and Profit are Negatively Correlated
# <li>Here is top 3 state where deals are Highest.
# <ol><li>Califonia
# <li>New York
# <li>Texas</ol>
# <li>Wyoming : Lowest Number of deal,Highest amount of sales = Wyoming(11.8%)
# <li>Lowest amount of sales = South Dakota(0.8%)
